# %%
import pandas as pd

# %%
df = pd.read_csv("StudentsPerformance.csv")

# %%
print(df.isnull().sum())
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# # Selecting numeric features for input (X) and output (y)

# %% [markdown]
# # feature matrix -> contains input variables (features) that the model uses to make predictions.
# # Target vector -> contains the output the model should predict.

# %%
X = df[['reading score', 'writing score']] # 2D matric
Y = df['math score'] # 1D vector

# %% [markdown]
# # Spliting data into test and training

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,  X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2, random_state = 42) 
# Here random_state means ->> random_state fixes the randomness so results stay consistent.
