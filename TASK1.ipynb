# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.3.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (91 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
# Using cached pandas-2.3.3-cp313-cp313-macosx_11_0_arm64.whl (10.7 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 3.6 MB/s  0:00:01 eta 0:00:01
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pandas]2m2/3 [pandas]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# # Reading CSV File

# %%
df = pd.read_csv("StudentsPerformance.csv")

# %% [markdown]
# # Printing the First Five rows

# %%
print("\nFIRST FIVE ROWS : \n")
print(df.iloc[0:5])
# Out:
# FIRST FIVE ROWS :
#
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course math score  reading score  writing score
# 0                    none         72             72             74
# 1               completed         69             90             88
# 2                    none         90             95             93
# 3                    none         47             57             44
# 4                    none         76             78             75

# %% [markdown]
# # DATA TYPES

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   object
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(2), object(6)
# memory usage: 62.6+ KB
# None

# %% [markdown]
# # CHECKING THE SHAPE OF THE DATA

# %%
print(df.shape)
# Out:
# (1000, 8)

# %% [markdown]
# # COLUMN NAME

# %%
print(df.describe(include="all"))
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
# mean       NaN            NaN                         NaN       NaN
# std        NaN            NaN                         NaN       NaN
# min        NaN            NaN                         NaN       NaN
# 25%        NaN            NaN                         NaN       NaN
# 50%        NaN            NaN                         NaN       NaN
# 75%        NaN            NaN                         NaN       NaN
# max        NaN            NaN                         NaN       NaN
#
#        test preparation course math score  reading score  writing score
# count                     1000       1000    1000.000000    1000.000000
# ...

# %% [markdown]
# # In the reading score , writing score and math score we can choose any two of them as independent variable and one of them will be dependent variable and we can train the data based one our values of independent and dependent varaible and later on we can predict the dependent variable based on our previous training
#
# # in this we will choose
# # X(independent variable) = writing score, reading score
# # Y(dependent variable) = math score
